# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
toko_sayuran = pd.read_csv("toko_sayuran.csv")
toko_sayuran.head(10)
# Out:
#                                                 Name  Description  \
# 0                               Toko sayur abah udin          NaN
# 1             Warung Sayur Gelombang Cinta Mang Dedi          NaN
# 2                                         Toko sayur          NaN
# 3  Toko Sayuran MM ( Mamah Bunga ) Pasar Modern B...          NaN
# 4                      Toko Sayur @sayuranKU_bandung          NaN
# 5                               Rumah Buah Tirtayasa          NaN
# 6                                  Rumah Sayur Kikan          NaN
# 7                                      Belanja Sayur          NaN
# 8                                 Toko sayur barokah          NaN
# 9                       Rumah Sayur Antapani Bandung          NaN
#
#                                          Fulladdress  \
# 0  Jl. Parakan Saat No.55, Antapani Tengah, Kec. ...
# 1  Jl. Ps. Sayati Lama, Sayati, Kec. Margahayu, K...
# 2  Jl. Pinus Raya No.50, Babakan Penghulu, Kec. C...
# ...

# %%
supermarket_sayuran = pd.read_csv("supermarket_sayuran.csv")
supermarket_sayuran.head(10)
# Out:
#                                                 Name  Description  \
# 0                               Toko sayur abah udin          NaN
# 1             Warung Sayur Gelombang Cinta Mang Dedi          NaN
# 2                                         Toko sayur          NaN
# 3  Toko Sayuran MM ( Mamah Bunga ) Pasar Modern B...          NaN
# 4                      Toko Sayur @sayuranKU_bandung          NaN
# 5                               Rumah Buah Tirtayasa          NaN
# 6                                  Rumah Sayur Kikan          NaN
# 7                                      Belanja Sayur          NaN
# 8                                 Toko sayur barokah          NaN
# 9                       Rumah Sayur Antapani Bandung          NaN
#
#                                          Fulladdress  \
# 0  Jl. Parakan Saat No.55, Antapani Tengah, Kec. ...
# 1  Jl. Ps. Sayati Lama, Sayati, Kec. Margahayu, K...
# 2  Jl. Pinus Raya No.50, Babakan Penghulu, Kec. C...
# ...

# %%
warung_sayuran = pd.read_csv("warung_sayuran.csv")
warung_sayuran.head(10)
# Out:
#                                                 Name  Description  \
# 0                               Toko sayur abah udin          NaN
# 1             Warung Sayur Gelombang Cinta Mang Dedi          NaN
# 2                                         Toko sayur          NaN
# 3  Toko Sayuran MM ( Mamah Bunga ) Pasar Modern B...          NaN
# 4                      Toko Sayur @sayuranKU_bandung          NaN
# 5                               Rumah Buah Tirtayasa          NaN
# 6                                  Rumah Sayur Kikan          NaN
# 7                                      Belanja Sayur          NaN
# 8                                 Toko sayur barokah          NaN
# 9                       Rumah Sayur Antapani Bandung          NaN
#
#                                          Fulladdress  \
# 0  Jl. Parakan Saat No.55, Antapani Tengah, Kec. ...
# 1  Jl. Ps. Sayati Lama, Sayati, Kec. Margahayu, K...
# 2  Jl. Pinus Raya No.50, Babakan Penghulu, Kec. C...
# ...

# %%
toko_sayuran_all_data = pd.concat([toko_sayuran, supermarket_sayuran, warung_sayuran], ignore_index=True)

# %%
toko_sayuran_all_data.to_csv("toko_sayuran_all_data.csv", index=False)
